# %% [markdown]
# Tutorial 3: Implement KNN and SVM

# %% [markdown]
# Exercise 1: K-Nearest Neighbor
#
# Let us implement the algorithm with the help of the 'Mobile.csv' dataset.
#
# It contains data about customers “Age”, “EstimatedSalary”, “Purchased” .
#
# Download the dataset from the shared folder.
#
#
# Predict if the customer will purchase a mobile or not.

# %%
import numpy as np;
import pandas as pd;
import matplotlib.pyplot as plt;

# %% [markdown]
# 1. load data : mobile.csv

# %%
df = pd.read_csv("C:\AI_ML\mobile.csv")

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.tail()
# Out:
#      Age  EstimatedSalary  Purchased
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
df.isna().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df['Purchased'].unique()
# Out:
# array([0, 1])

# %%
purchased_data = df[["Age" , "EstimatedSalary", "Purchased"]] [df["Purchased"] == 1]
purchased_data
# Out:
#      Age  EstimatedSalary  Purchased
# 7     32           150000          1
# 16    47            25000          1
# 17    45            26000          1
# 18    46            28000          1
# 19    48            29000          1
# ..   ...              ...        ...
# 393   60            42000          1
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 399   49            36000          1
#
# [143 rows x 3 columns]

# %%
not_purchased_data = df[["Age" , "EstimatedSalary", "Purchased"]] [df["Purchased"] == 0]
not_purchased_data
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 377   42            53000          0
# 380   42            64000          0
# 387   39            71000          0
# 394   39            59000          0
# 398   36            33000          0
#
# [257 rows x 3 columns]

# %%
plt.scatter(purchased_data["Age"], purchased_data["EstimatedSalary"], color="green")
plt.scatter(not_purchased_data["Age"], not_purchased_data["EstimatedSalary"], color="red")

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df["EstimatedSalary"].max()
# Out:
# 150000

# %%
df["EstimatedSalary"].min()
# Out:
# 15000

# %%
df["Age"].max()
# Out:
# 60

# %%
df["Age"].min()
# Out:
# 18

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
features_of_scale = ["Age", "EstimatedSalary"]
scaled_values = scaler.fit_transform(df[features_of_scale])

# %%
df["norm_age"] = scaled_values[:,0]
df["norm_salary"] = scaled_values[:,1]

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased  norm_age  norm_salary
# 0     19            19000          0  0.023810     0.029630
# 1     35            20000          0  0.404762     0.037037
# 2     26            43000          0  0.190476     0.207407
# 3     27            57000          0  0.214286     0.311111
# 4     19            76000          0  0.023810     0.451852
# ..   ...              ...        ...       ...          ...
# 395   46            41000          1  0.666667     0.192593
# 396   51            23000          1  0.785714     0.059259
# 397   50            20000          1  0.761905     0.037037
# 398   36            33000          0  0.428571     0.133333
# 399   49            36000          1  0.738095     0.155556
#
# [400 rows x 5 columns]

# %%
df["norm_age"].min()
# Out:
# 0.0

# %%
df["norm_age"].max()
# Out:
# 0.9999999999999998

# %%
df["norm_salary"].min()
# Out:
# 0.0

# %%
df["norm_salary"].max()
# Out:
# 1.0

# %%
X = df[['norm_age', 'norm_salary']]
y = df['Purchased']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)
print("Shape of X_train", X_train.shape)
print("Shape of X_test", X_test.shape)
print("Shape of y_train", y_train.shape)
print("Shape of y_test", y_test.shape)
# Out:
# Shape of X_train (320, 2)
# Shape of X_test (80, 2)
# Shape of y_train (320,)
# Shape of y_test (80,)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5,metric="euclidean")
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
model.score(X_train, y_train) * 100
# Out:
# 91.875

# %%
model.score(X_test, y_test) * 100
# Out:
# 95.0

# %% [markdown]
# Exercise 2: SVM for classification
#
# Consider the Iris dataset which provides measurements of sepal length, sepal width, petal length, and petal width for 50 flowers from each of 3 species. Total rows are 150.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
iris_data = pd.read_csv("C:\AI_ML\iris.csv")

# %%
iris_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 7.2 KB

# %%
iris_data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data.tail()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris_data.isna().sum()
# Out:
# Sepal.Length    0
# Sepal.Width     0
# Petal.Length    0
# Petal.Width     0
# Species         0
# dtype: int64

# %%
iris_data['Species'].unique()
# Out:
# <ArrowStringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str

# %% [markdown]
# Create Binary Class SVM model

# %%
v_nv_fn = lambda x: 0 if x=="versicolor" else 1

# new column added into dataframe
iris_data["v_nv"] = iris_data["Species"].apply(v_nv_fn)

#iris_data[iris_data["v_nv"] == 0]
iris_data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  v_nv
# 0             5.1          3.5           1.4          0.2     setosa     1
# 1             4.9          3.0           1.4          0.2     setosa     1
# 2             4.7          3.2           1.3          0.2     setosa     1
# 3             4.6          3.1           1.5          0.2     setosa     1
# 4             5.0          3.6           1.4          0.2     setosa     1
# ..            ...          ...           ...          ...        ...   ...
# 145           6.7          3.0           5.2          2.3  virginica     1
# 146           6.3          2.5           5.0          1.9  virginica     1
# 147           6.5          3.0           5.2          2.0  virginica     1
# 148           6.2          3.4           5.4          2.3  virginica     1
# 149           5.9          3.0           5.1          1.8  virginica     1
#
# [150 rows x 6 columns]

# %%
import seaborn as sns
sns.pairplot(iris_data, x_vars="Petal.Length", y_vars="Petal.Width", hue="v_nv", height=5)

# %%
from sklearn.svm import SVC
X = iris_data[["Petal.Length", "Petal.Width"]]
y = iris_data["v_nv"]
model = SVC()
model.fit(X,y)
model.score(X,y) * 100
# Out:
# 95.33333333333334

# %% [markdown]
# Model Vizulatization

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\alias\anaconda3\lib\site-packages (0.24.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy>=1.16.3 in c:\users\alias\anaconda3\lib\site-packages (from mlxtend) (1.17.0)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\alias\anaconda3\lib\site-packages (from mlxtend) (2.4.2)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\alias\anaconda3\lib\site-packages (from mlxtend) (3.0.0)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\alias\anaconda3\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\alias\anaconda3\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\alias\anaconda3\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alias\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\alias\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alias\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alias\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\alias\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\alias\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\alias\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alias\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\alias\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\alias\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\alias\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\alias\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\alias\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\alias\anaconda3\Lib\site-packages)

# %%
from mlxtend.plotting import plot_decision_regions
features = np.array(X)
target = np.array(y)
plot_decision_regions(features, target, clf=model)
plt.xlabel("Petal length")
plt.ylabel("Petal width")
plt.title("Decision boundary of SVM on iris data")
# Out:
# c:\Users\alias\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# Text(0.5, 1.0, 'Decision boundary of SVM on iris data')

# %% [markdown]
# Create Multi Class SVM model

# %% [markdown]
# Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
iris_data["Species"] = le.fit_transform(iris_data["Species"])
iris_data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species  v_nv
# 0             5.1          3.5           1.4          0.2        0     1
# 1             4.9          3.0           1.4          0.2        0     1
# 2             4.7          3.2           1.3          0.2        0     1
# 3             4.6          3.1           1.5          0.2        0     1
# 4             5.0          3.6           1.4          0.2        0     1
# ..            ...          ...           ...          ...      ...   ...
# 145           6.7          3.0           5.2          2.3        2     1
# 146           6.3          2.5           5.0          1.9        2     1
# 147           6.5          3.0           5.2          2.0        2     1
# 148           6.2          3.4           5.4          2.3        2     1
# 149           5.9          3.0           5.1          1.8        2     1
#
# [150 rows x 6 columns]

# %%
X = iris_data[["Petal.Length", "Petal.Width"]]
y = iris_data["Species"]
model = SVC()
model.fit(X,y)
# Out:
# SVC()

# %%
from mlxtend.plotting import plot_decision_regions
features = np.array(X)
target = np.array(y)

plot_decision_regions(features,target, clf=model)
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.title("Multiclass classification on iris using SVM")
# Out:
# c:\Users\alias\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# Text(0.5, 1.0, 'Multiclass classification on iris using SVM')
