# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('computers.csv')

# %%
df.head()
# Out:
#    Units  Minutes
# 0      1       23
# 1      2       29
# 2      3       49
# 3      4       64
# 4      4       74

# %%
X = df[['Units']].values
y = df['Minutes']

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
lr.predict([[6]])
# Out:
# array([97.21428571])

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [15.50877193]
# 4.161654135338296

# %%
df.head(10)
# Out:
#    Units  Minutes
# 0      1       23
# 1      2       29
# 2      3       49
# 3      4       64
# 4      4       74
# 5      5       87
# 6      6       96
# 7      6       97
# 8      7      109
# 9      8      119

# %%
plt.scatter(X,y)

# %%
df.head()
# Out:
#    Units  Minutes
# 0      1       23
# 1      2       29
# 2      3       49
# 3      4       64
# 4      4       74

# %%
model_0 = 10 + 12 * df['Units']
model_1 = 6 + 18 * df['Units']
model_2 = 4.161654135338296 + 15.50877193 * df['Units']

model_2
# Out:
# 0      19.670426
# 1      35.179198
# 2      50.687970
# 3      66.196742
# 4      66.196742
# 5      81.705514
# 6      97.214286
# 7      97.214286
# 8     112.723058
# 9     128.231830
# 10    143.740602
# 11    143.740602
# 12    159.249373
# 13    159.249373
# Name: Units, dtype: float64

# %%
df['model_0'] = model_0
df['model_1'] = model_1
df['model_2'] = model_2

# %%
df.head(10)
# Out:
#    Units  Minutes  model_0  model_1     model_2
# 0      1       23       22       24   19.670426
# 1      2       29       34       42   35.179198
# 2      3       49       46       60   50.687970
# 3      4       64       58       78   66.196742
# 4      4       74       58       78   66.196742
# 5      5       87       70       96   81.705514
# 6      6       96       82      114   97.214286
# 7      6       97       82      114   97.214286
# 8      7      109       94      132  112.723058
# 9      8      119      106      150  128.231830

# %%
# rsq = model_2.score(df['Units'],df['model_2'])

# %%
student = pd.read_csv('std_marks_data.csv')

# %%
student.head()
# Out:
#    hours  age  internet  marks
# 0   6.84   15         0  78.64
# 1   6.56   20         1  88.80
# 2    NaN   21         1  88.90
# 3   8.67   22         1  98.99
# 4   7.55   17         1  92.34

# %%
student.isnull().sum()
# Out:
# hours       12
# age          0
# internet     0
# marks        0
# dtype: int64

# %%
student['hours'] = student['hours'].fillna(student['hours'].mean())

# %%
student.isnull().sum()
# Out:
# hours       0
# age         0
# internet    0
# marks       0
# dtype: int64

# %%
student.head()
# Out:
#       hours  age  internet  marks
# 0  6.840000   15         0  78.64
# 1  6.560000   20         1  88.80
# 2  5.494514   21         1  88.90
# 3  8.670000   22         1  98.99
# 4  7.550000   17         1  92.34

# %%
X = student.iloc[:,:2].values
y = student['marks']

X
# Out:
# array([[ 6.84      , 15.        ],
#        [ 6.56      , 20.        ],
#        [ 5.49451389, 21.        ],
#        [ 8.67      , 22.        ],
#        [ 7.55      , 17.        ],
#        [ 8.8       , 16.        ],
#        [ 8.76      , 24.        ],
#        [ 7.44      , 25.        ],
#        [ 1.23      , 21.        ],
#        [ 4.24      , 16.        ],
#        [ 3.85      , 15.        ],
#        [ 6.4       , 17.        ],
#        [ 4.        , 16.        ],
#        [ 6.8       , 18.        ],
#        [ 6.2       , 18.        ],
#        [ 1.7       , 20.        ],
#        [ 0.5       , 21.        ],
#        [ 5.34      , 22.        ],
#        [ 5.67      , 23.        ],
#        [ 4.8       , 24.        ],
#        [ 2.99      , 25.        ],
#        [ 6.55      , 21.        ],
#        [ 9.33      , 16.        ],
#        [ 4.44      , 18.        ],
#        [ 2.22      , 24.        ],
#        [ 1.11      , 25.        ],
#        [ 8.01      , 15.        ],
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y ,test_size=0.2, random_state=35)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test,y_pred)
# Out:
# 0.06677222640596059
