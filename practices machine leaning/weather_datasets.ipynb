# %%
print('govinda')
# Out:
# govinda

# %%
import time

# %%
for i in range(10):
    time.sleep(1)
    print('Govinda Kumar')
    time.sleep(2)
    print(i)
    time.sleep(3)
    print("Hero")
# Out:
# Govinda Kumar
# 0
# Hero
# Govinda Kumar
# 1
# Hero
# Govinda Kumar
# 2
# Hero
# Govinda Kumar
# 3
# Hero
# Govinda Kumar
# 4
# Hero
# Govinda Kumar
# 5
# Hero
# Govinda Kumar
# 6
# Hero
# Govinda Kumar
# 7
# Hero
# Govinda Kumar
# 8
# Hero
# Govinda Kumar
# 9
# Hero

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
